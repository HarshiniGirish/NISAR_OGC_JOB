# %% [markdown]
# # Sample packaging notebook

# %%
input_uri = "s3://example-bucket/sample.nc"
bbox = ""
out_name = "subset.zarr"

# %%
from pathlib import Path

import xarray as xr

out_dir = Path("output")
out_dir.mkdir(parents=True, exist_ok=True)
dataset = xr.open_dataset(input_uri)
dataset.to_zarr(out_dir / out_name)
